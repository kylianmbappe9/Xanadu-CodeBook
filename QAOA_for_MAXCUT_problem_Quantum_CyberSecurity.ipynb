# %% [markdown]
# <a href="https://colab.research.google.com/github/kylianmbappe9/Xanadu-CodeBook/blob/main/QAOA_for_MAXCUT_problem_Quantum_CyberSecurity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Image 1, basic QAOA operation for MAXCUT problem")

# %% [markdown]
# ![QAOA FOR MACUT_241001_001026_1.jpg](data:image/jpeg;base64,...)

# %%
# !pip install pennylane
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 18.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 kB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.3/15.3 MB 63.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 64.8 MB/s eta 0:00:00
# ...

# %%
import pennylane
import numpy as np
from pennylane import numpy as pnp

np.random.seed(42)

# %% [markdown]
# ![Notes_241001_010500 (1).jpg](data:image/jpeg;base64,...)
